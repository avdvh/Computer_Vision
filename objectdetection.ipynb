# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image (replace this with your image loading code)
image = cv2.imread('bird.jpg')

# Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply edge detection using Canny
edges = cv2.Canny(gray_image, threshold1=100, threshold2=200)

# Find contours in the edge image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw bounding boxes around detected objects
detected_objects_image = image.copy()
for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(detected_objects_image, (x, y), (x + w, y + h), (0, 255, 0), 2)

# Display the resulting image with bounding boxes
plt.imshow(cv2.cvtColor(detected_objects_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
